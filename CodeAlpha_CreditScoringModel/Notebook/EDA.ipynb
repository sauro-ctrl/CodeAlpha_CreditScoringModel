# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("Data/credit_data.csv")
df.head()
# Out:
#     Age  Annual_Income  Employment_Years  Monthly_Debt  Debt_to_Income  \
# 0  43.0       120000.0              12.0        2150.0            0.22
# 1  29.0        48000.0               6.0         950.0            0.24
# 2  55.0        95000.0              30.0        1200.0            0.15
# 3  38.0        60000.0              10.0        1300.0            0.26
# 4  27.0        37000.0               3.0         800.0            0.25
#
#    Credit_Utilization  Late_Payments  Credit_History_Years  Credit_Accounts  \
# 0                28.0            0.0                    18                6
# 1                38.0            1.0                     7                4
# 2                22.0            0.0                    34               10
# 3                45.0            2.0                    14                5
# 4                40.0            1.0                     5                3
#
#    Loan_Amount  Previous_Defaults  Payment_History_Score Home_Ownership  \
# ...

# %%
df.isnull().sum()
# Out:
# Age                      1
# Annual_Income            2
# Employment_Years         2
# Monthly_Debt             4
# Debt_to_Income           0
# Credit_Utilization       2
# Late_Payments            2
# Credit_History_Years     0
# Credit_Accounts          0
# Loan_Amount              3
# Previous_Defaults        2
# Payment_History_Score    2
# Home_Ownership           2
# Marital_Status           3
# Education_Level          2
# Creditworthy             0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 639 entries, 0 to 638
# Data columns (total 16 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Age                    638 non-null    float64
#  1   Annual_Income          637 non-null    float64
#  2   Employment_Years       637 non-null    float64
#  3   Monthly_Debt           635 non-null    float64
#  4   Debt_to_Income         639 non-null    float64
#  5   Credit_Utilization     637 non-null    float64
#  6   Late_Payments          637 non-null    float64
#  7   Credit_History_Years   639 non-null    int64
#  8   Credit_Accounts        639 non-null    int64
#  9   Loan_Amount            636 non-null    float64
#  10  Previous_Defaults      637 non-null    float64
#  11  Payment_History_Score  637 non-null    float64
#  12  Home_Ownership         637 non-null    str
#  13  Marital_Status         636 non-null    str
#  14  Education_Level        637 non-null    str
# ...

# %%
df["Creditworthy"].value_counts().plot(
    kind="bar"
)

plt.title("Creditworthiness Distribution")
plt.xlabel("Status")
plt.ylabel("Count")
plt.show()

# %%
plt.scatter(
    df["Annual_Income"],
    df["Creditworthy"]
)

plt.title("Income vs Creditworthiness")
plt.xlabel("Income")
plt.ylabel("Creditworthiness")
plt.show()

# %%
plt.scatter(
    df["Loan_Amount"],
    df["Creditworthy"]
)

plt.title("Loan Amount vs Creditworthiness")
plt.xlabel("Loan_Amount")
plt.ylabel("Creditworthiness")
plt.show()

# %%
plt.hist(
    df["Annual_Income"],
    bins=20
)

plt.title("Income Distribution")
plt.xlabel("Annual Income")
plt.ylabel("Frequency")
plt.show()

# %%
corr = df.corr(numeric_only=True)

plt.figure(figsize=(10,8))

plt.imshow(corr)

plt.xticks(
    range(len(corr.columns)),
    corr.columns,
    rotation=90
)

plt.yticks(
    range(len(corr.columns)),
    corr.columns
)

plt.colorbar()

plt.title("Correlation Matrix")

plt.show()
